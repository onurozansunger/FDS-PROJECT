# %% [markdown]
# <a href="https://colab.research.google.com/github/onurozansunger/FDS-PROJECT/blob/main/salaky%C3%B6ntemi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
netflix4 = pd.read_csv('/content/netflix4.csv')

# %%
netflix4.head()
# Out:
#   show_id     type                 title        country  release_year rating  \
# 0      s1    Movie  Dick Johnson Is Dead  United States          2020  PG-13
# 1      s1    Movie  Dick Johnson Is Dead  United States          2020  PG-13
# 2      s2  TV Show         Blood & Water   South Africa          2021  TV-MA
# 3      s2  TV Show         Blood & Water   South Africa          2021  TV-MA
# 4      s2  TV Show         Blood & Water   South Africa          2021  TV-MA
#
#    averageRating  numVotes                       genres  directors  category  \
# 0            7.4    7119.0  Biography,Documentary,Drama  nm0990310     actor
# 1            7.4    7119.0  Biography,Documentary,Drama  nm0990310   actress
# 2            8.0      22.0            Crime,Documentary  nm1520612   actress
# 3            7.3     528.0          Crime,Drama,Mystery  nm0809375  director
# 4            7.3     528.0          Crime,Drama,Mystery  nm0809375     actor
#
#       primaryName
# 0   Michael Hilow
# 1     Ana Hoffman
# 2  Susan Sarandon
# 3      Mike Smith
# 4       Neill Rea

# %%
netflix4.drop([ 'directors', 'title'], axis=1, inplace=True)

# %%
netflix5=netflix4[netflix4['category']=='director']

# %%
netflix5.drop([ 'show_id'], axis=1, inplace=True)

# %%
netflix5.drop(['release_year'], axis=1, inplace=True)

# %%
netflix5.head()
# Out:
#        type       country rating  averageRating  numVotes  \
# 3   TV Show  South Africa  TV-MA            7.3     528.0
# 7   TV Show  South Africa  TV-MA            8.0      22.0
# 31  TV Show           NaN  TV-MA            7.2      11.0
# 45  TV Show           NaN  TV-MA            7.6      55.0
# 54  TV Show           NaN  TV-MA            2.5     477.0
#
#                  genres  category   primaryName
# 3   Crime,Drama,Mystery  director    Mike Smith
# 7     Crime,Documentary  director    Steve Rivo
# 31          Crime,Short  director   Paul Desira
# 45                Drama  director  Jirí Krejcík
# 54               Horror  director  Tony Mandile

# %%
netflix5.columns
# Out:
# Index(['type', 'country', 'rating', 'averageRating', 'numVotes', 'genres',
#        'category', 'primaryName'],
#       dtype='object')

# %%
# 'rating' sütununu string'e dönüştürme
netflix5['rating'] = netflix5['rating'].astype(str)

# 'genres', 'country', 'primaryName' sütunlarını liste haline getirme ve 'type' sütununu binary'e dönüştürme
netflix5['genres'] = netflix5['genres'].apply(lambda x: x.split(',') if isinstance(x, str) else [])
netflix5['country'] = netflix5['country'].apply(lambda x: x.split(',') if isinstance(x, str) else [])
netflix5['primaryName'] = netflix5['primaryName'].apply(lambda x: x.split(',') if isinstance(x, str) else [])
netflix5['type'] = netflix5['type'].apply(lambda x: 1 if x == 'Movie' else 0)

# 'rating', 'genres', 'country', 'primaryName' için benzersiz değerleri elde etme ve one-hot encoding uygulama
unique_ratings = netflix5['rating'].unique()
for rating in unique_ratings:
    netflix5['Rating_' + rating] = netflix5['rating'].apply(lambda x: 1 if x == rating else 0)

all_genres = sum(netflix5['genres'], [])
unique_genres = set(all_genres)
for genre in unique_genres:
    netflix5['Genre_' + genre] = netflix5['genres'].apply(lambda x: 1 if genre in x else 0)

all_countries = sum(netflix5['country'], [])
unique_countries = set(all_countries)
for country in unique_countries:
    netflix5['Country_' + country] = netflix5['country'].apply(lambda x: 1 if country in x else 0)

all_names = sum(netflix5['primaryName'], [])
unique_names = set(all_names)
for name in unique_names:
    netflix5['Name_' + name] = netflix5['primaryName'].apply(lambda x: 1 if name in x else 0)

# Orijinal kategorik sütunları kaldırma
netflix5.drop(['genres', 'country', 'primaryName', 'rating'], axis=1, inplace=True)

# Yeni DataFrame'in ilk beş satırını gösterme
print(netflix5.head())
# Out:
#     type  averageRating  numVotes  category  Rating_TV-MA  Rating_PG  \
# 3      0            7.3     528.0  director             1          0
# 7      0            8.0      22.0  director             1          0
# 31     0            7.2      11.0  director             1          0
# 45     0            7.6      55.0  director             1          0
# 54     0            2.5     477.0  director             1          0
#
#     Rating_PG-13  Rating_TV-PG  Rating_TV-14  Rating_TV-Y  ...  \
# 3              0             0             0            0  ...
# 7              0             0             0            0  ...
# 31             0             0             0            0  ...
# 45             0             0             0            0  ...
# 54             0             0             0            0  ...
#
#     Name_Pat Necerato  Name_Frode Klevstul  Name_Sharan Sharma  \
# 3                   0                    0                   0
# 7                   0                    0                   0
# 31                  0                    0                   0
# 45                  0                    0                   0
# 54                  0                    0                   0
#
#     Name_Andrew Cymek  Name_Joseph Riggi  Name_John Herzfeld  Name_Viet Max  \
# 3                   0                  0                   0              0
# 7                   0                  0                   0              0
# 31                  0                  0                   0              0
# 45                  0                  0                   0              0
# 54                  0                  0                   0              0
#
#     Name_Per-Olav Sørensen  Name_Luke Bradford  Name_Robert Stevens
# 3                        0                   0                    0
# 7                        0                   0                    0
# 31                       0                   0                    0
# 45                       0                   0                    0
# 54                       0                   0                    0
#
# [5 rows x 16559 columns]

# %%
netflix5.drop(['category'], axis=1, inplace=True)

# %%
netflix5.head()
# Out:
#     type  averageRating  numVotes  Rating_TV-MA  Rating_PG  Rating_PG-13  \
# 3      0            7.3     528.0             1          0             0
# 7      0            8.0      22.0             1          0             0
# 31     0            7.2      11.0             1          0             0
# 45     0            7.6      55.0             1          0             0
# 54     0            2.5     477.0             1          0             0
#
#     Rating_TV-PG  Rating_TV-14  Rating_TV-Y  Rating_TV-Y7  ...  \
# 3              0             0            0             0  ...
# 7              0             0            0             0  ...
# 31             0             0            0             0  ...
# 45             0             0            0             0  ...
# 54             0             0            0             0  ...
#
#     Name_Pat Necerato  Name_Frode Klevstul  Name_Sharan Sharma  \
# 3                   0                    0                   0
# 7                   0                    0                   0
# 31                  0                    0                   0
# 45                  0                    0                   0
# 54                  0                    0                   0
#
#     Name_Andrew Cymek  Name_Joseph Riggi  Name_John Herzfeld  Name_Viet Max  \
# 3                   0                  0                   0              0
# 7                   0                  0                   0              0
# 31                  0                  0                   0              0
# 45                  0                  0                   0              0
# 54                  0                  0                   0              0
#
#     Name_Per-Olav Sørensen  Name_Luke Bradford  Name_Robert Stevens
# 3                        0                   0                    0
# 7                        0                   0                    0
# 31                       0                   0                    0
# 45                       0                   0                    0
# 54                       0                   0                    0
#
# [5 rows x 16558 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline


# Özellikleri ve hedef değişkenleri ayır
X = netflix5.drop(['averageRating', 'numVotes'], axis=1)
y_rating = netflix5['averageRating']
y_votes = netflix5['numVotes']

# Eğitim ve test setlerini ayır
X_train, X_test, y_rating_train, y_rating_test = train_test_split(X, y_rating, test_size=0.2, random_state=0)
_, _, y_votes_train, y_votes_test = train_test_split(X, y_votes, test_size=0.2, random_state=0)

# Modeli her hedef için ayrı ayrı oluştur
model_rating = Pipeline([
    # ('polynomial_features', PolynomialFeatures(degree=2)),  # Polinom özellikler ekleme (isteğe bağlı)
    ('linear_regression', LinearRegression())  # Lineer regresyon modeli
])

model_votes = Pipeline([
    # ('polynomial_features', PolynomialFeatures(degree=2)),  # Polinom özellikler ekleme (isteğe bağlı)
    ('linear_regression', LinearRegression())  # Lineer regresyon modeli
])

# Her modeli ayrı ayrı eğit
model_rating.fit(X_train, y_rating_train)
model_votes.fit(X_train, y_votes_train)

# Model performansını değerlendir
scores_rating = cross_val_score(model_rating, X_train, y_rating_train, cv=5)
scores_votes = cross_val_score(model_votes, X_train, y_votes_train, cv=5)

print(f'Çapraz doğrulama skorları (rating): {scores_rating}')
print(f'Ortalama skor (rating): {scores_rating.mean()}')
print(f'Çapraz doğrulama skorları (votes): {scores_votes}')
print(f'Ortalama skor (votes): {scores_votes.mean()}')
# Out:
# Çapraz doğrulama skorları (rating): [-9.87422606e+22 -1.15755253e+23 -1.98988210e+23 -2.36844467e+23
#  -1.00845438e+23]
# Ortalama skor (rating): -1.5023512588715642e+23
# Çapraz doğrulama skorları (votes): [-7.63788572e+23 -5.37131161e+23 -5.78699370e+23 -3.22119905e+23
#  -1.07387333e+22]
# Ortalama skor (votes): -4.424955481222217e+23

# %%
model_rating.named_steps['feature_selection'].get_support()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-522f8d676fe1> in <cell line: 1>()
# ----> 1 model_rating.named_steps['feature_selection'].get_support()
#
# KeyError: 'feature_selection'
